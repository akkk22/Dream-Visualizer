# %% [markdown]
# <a href="https://colab.research.google.com/github/akkk22/Dream-Visualizer/blob/main/Dream_Visualizer.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install diffusers transformers accelerate torch gradio safetensors --quiet

# %%
import torch
print("Torch version:", torch.__version__)
print("CUDA available:", torch.cuda.is_available())
print("CUDA version:", torch.version.cuda)
# Out:
# Torch version: 2.8.0+cu126
# CUDA available: True
# CUDA version: 12.6

# %%
import random

dream_prompts = [
    "A castle floating in the clouds, surrounded by rainbow waterfalls 🌈",
    "A neon dragon flying across a cyberpunk skyline 🐉",
    "A galaxy made of glowing jellyfish swimming through space 🌌",
    "An endless library where the books whisper dreams 📚✨"
]

def random_dream():
    return random.choice(dream_prompts)

    with gr.Row():
     dream_box = gr.Textbox(label="Describe your dream...")
     inspire_btn = gr.Button("✨ Inspire Me")

     inspire_btn.click(fn=random_dream, outputs=dream_box)

# %%
import torch
from diffusers import StableDiffusionPipeline
import gradio as gr

# Load model (artistic dreamlike)
model_id = "prompthero/openjourney"

pipe = StableDiffusionPipeline.from_pretrained(model_id)
pipe = pipe.to("cuda") if torch.cuda.is_available() else pipe.to("cpu")
# Out:
# Loading pipeline components...:   0%|          | 0/7 [00:00<?, ?it/s]

# %%
import gradio as gr
import random
import os

# Dream prompt ideas for "Surprise Me!"
dream_prompts = [
    "A castle floating among the clouds",
    "A neon tiger walking through a cyberpunk city",
    "An endless library with glowing books",
    "A galaxy inside a glass jar",
    "A girl with butterfly wings under a surreal sky"
]

# Function to generate dream image
def generate(prompt, style):
    full_prompt = f"{prompt}, {style} style"
    image = pipe(full_prompt).images[0]

    filename = "dream.png"
    image.save(filename)
    return image, filename

# Function to give random "Surprise Me!" prompt
def surprise_prompt():
    return random.choice(dream_prompts), "🌌 Surreal Dreamscape"

# 🌌 Starry dreamy CSS with twinkling + multiple shooting stars
custom_css = """
/* General page setup */
/* General page setup */
body {
  margin: 0;
  padding: 0;
  min-height: 100vh;
  font-family: 'Trebuchet MS', sans-serif;
  color: #ffffff;
  background: radial-gradient(circle at top, #1a0033, #000010, #050013); /* deep night gradient */
  overflow-x: hidden;
  overflow-y: auto;
}

/* Transparent Gradio bg */
#root, .gradio-container, .gradio-app, .block, .wrap, .main {
  background: transparent !important;
}

/* ✨ Static tiny stars (background dots) */
body::after {
  content: '';
  position: fixed;
  top: 0;
  left: 0;
  width: 100%;
  height: 100%;
  background:
    radial-gradient(1px 1px at 10% 20%, #fff, transparent),
    radial-gradient(1px 1px at 30% 80%, #fff, transparent),
    radial-gradient(1px 1px at 70% 60%, #fff, transparent),
    radial-gradient(1px 1px at 90% 40%, #fff, transparent),
    radial-gradient(1px 1px at 50% 10%, #fff, transparent),
    radial-gradient(1px 1px at 80% 90%, #fff, transparent);
  background-repeat: repeat;
  opacity: 0.9;
  z-index: -3;
}

/* ✨ Twinkling overlay */
body::before {
  content: '';
  position: fixed;
  top: 0;
  left: 0;
  width: 100%;
  height: 100%;
  background: url("https://i.ibb.co/vs9FZyH/twinkling.png") repeat;
  opacity: 0.6;
  animation: twinkle 6s infinite alternate;
  z-index: -2;
}

@keyframes twinkle {
  from { opacity: 0.3; }
  to   { opacity: 0.9; }
}

/* 🌟 Extra glowing stars */
.stars {
  position: fixed;
  top: 0;
  left: 0;
  width: 100%;
  height: 100%;
  pointer-events: none;
  z-index: -4;
  background:
    radial-gradient(2px 2px at 20% 30%, #fff, transparent),
    radial-gradient(2px 2px at 40% 70%, #fff, transparent),
    radial-gradient(2px 2px at 60% 20%, #fff, transparent),
    radial-gradient(2px 2px at 80% 50%, #fff, transparent);
  background-repeat: repeat;
  animation: starTwinkle 4s ease-in-out infinite alternate;
}

@keyframes starTwinkle {
  from { opacity: 0.5; transform: scale(0.9); }
  to   { opacity: 1; transform: scale(1.1); }
}

/* 🌠 Shooting stars */
.shooting-star {
  position: fixed;
  top: -20px;
  width: 120px;
  height: 3px;
  background: linear-gradient(to left, white, transparent);
  opacity: 0.8;
  transform: rotate(45deg);
  animation: shooting 4s linear infinite;
}

@keyframes shooting {
  0%   { transform: translate(var(--start-x, 0), var(--start-y, 0)) rotate(45deg); opacity: 0; }
  10%  { opacity: 1; }
  100% { transform: translate(120vw, 120vh) rotate(45deg); opacity: 0; }
}

/* 🌙 Floating glowing moon */
.moon {
  position: absolute;
  top: 50px;
  right: 80px;
  width: 100px;
  height: 100px;
  background: radial-gradient(circle, #fffacd, #f0e68c, #daa520);
  border-radius: 50%;
  box-shadow: 0 0 40px #fffacd;
  animation: floatMoon 8s ease-in-out infinite alternate;
  z-index: -1;
}

@keyframes floatMoon {
  from { transform: translateY(0px); }
  to   { transform: translateY(30px); }
}

/* ✨ Neon Title */
h1 {
  font-size: 2.8rem;
  text-align: center;
  color: #8a00c2;
  text-shadow:
    0 0 8px rgba(138, 0, 194, 0.6),
    0 0 15px rgba(138, 0, 194, 0.4),
    0 0 25px rgba(138, 0, 194, 0.2);
  font-family: 'Poppins', sans-serif;
  margin-bottom: 15px;
}

/* 🎨 Buttons */
button {
  border-radius: 14px !important;
  font-size: 16px !important;
  background: linear-gradient(90deg, #8a00c2, #4b0082);
  color: white !important;
  border: none !important;
  box-shadow: 0 0 14px #8a00c2;
  transition: all 0.3s ease-in-out;
}
button:hover {
  transform: scale(1.05);
  box-shadow: 0 0 24px #8a00c2;
}


/* 🌌 Starry glowing night background */
body {
  margin: 0;
  padding: 0;
  min-height: 100vh;
  font-family: 'Trebuchet MS', sans-serif;
  color: #ffffff;
  background: radial-gradient(circle at top, #1a0033, #000010, #050013); /* starry gradient */
  overflow-x: hidden;
  overflow-y: auto;
}

/* ✨ Glowing stars layer */
body::after {
  content: '';
  position: fixed;
  top: 0;
  left: 0;
  width: 100%;
  height: 100%;
  background: radial-gradient(2px 2px at 20% 30%, #fff, transparent),
              radial-gradient(2px 2px at 40% 70%, #fff, transparent),
              radial-gradient(2px 2px at 60% 20%, #fff, transparent),
              radial-gradient(2px 2px at 80% 50%, #fff, transparent),
              radial-gradient(2px 2px at 30% 80%, #fff, transparent),
              radial-gradient(2px 2px at 70% 60%, #fff, transparent);
  background-repeat: repeat;
  opacity: 0.9;
  z-index: -3;
  animation: starGlow 4s ease-in-out infinite alternate;
}

/* 🌟 Star glow animation */
@keyframes starGlow {
  from { opacity: 0.6; filter: blur(0px); }
  to   { opacity: 1; filter: blur(1px); }
}

/* 🌟 Extra glowing stars layer */
.stars {
  position: fixed;
  top: 0;
  left: 0;
  width: 100%;
  height: 100%;
  pointer-events: none;
  z-index: -4;
  background:
    radial-gradient(2px 2px at 10% 20%, #fff, transparent),
    radial-gradient(2px 2px at 30% 80%, #fff, transparent),
    radial-gradient(2px 2px at 70% 60%, #fff, transparent),
    radial-gradient(2px 2px at 90% 40%, #fff, transparent),
    radial-gradient(2px 2px at 50% 10%, #fff, transparent),
    radial-gradient(2px 2px at 80% 90%, #fff, transparent);
  background-repeat: repeat;
  animation: starTwinkle 5s ease-in-out infinite alternate;
}

@keyframes starTwinkle {
  from { opacity: 0.5; }
  to   { opacity: 1; }
}
"""

# 🌙 Build Gradio UI
with gr.Blocks(css=custom_css, title="Dream Visualizer ✨") as demo:

    # 🎼 Background Music
    gr.HTML("""
    <audio autoplay loop style="display:none">
      <source src="https://files.freemusicarchive.org/storage-freemusicarchive-org/music/no_curator/Scott_Holmes_Music/Ambient/Ambient_-_Scott_Holmes_Music_-_04_-_Soothing_Ambience.mp3" type="audio/mpeg">
    </audio>
    """)

# 🎨 Title
    gr.HTML("<h1>🌙 Dream Visualizer ✨</h1>")

# 🌌 Static glowing stars background
    gr.HTML('<div class="stars"></div>')

# 🌠 Shooting stars + 🌙 Moon overlay

    gr.HTML("""
    <div class="shooting-star" style="--start-x: -20vw; --start-y: -10vh; animation-delay: 1s;"></div>
    <div class="shooting-star" style="--start-x: 10vw; --start-y: -20vh; animation-delay: 4s;"></div>
    <div class="shooting-star" style="--start-x: -40vw; --start-y: -30vh; animation-delay: 7s;"></div>
    <div class="shooting-star" style="--start-x: 20vw; --start-y: -15vh; animation-delay: 10s;"></div>
    <div class="shooting-star" style="--start-x: -30vw; --start-y: -25vh; animation-delay: 14s;"></div>
    <div class="moon"></div>
    """)

    gr.Markdown("### Turn your imagination into glowing dreamscapes...")

    with gr.Row():
        prompt = gr.Textbox(label="💭 Describe your dream...", placeholder="e.g. A castle floating in neon clouds...")
        style = gr.Dropdown(
            choices=["🌌 Surreal Dreamscape", "🎨 Realistic", "🌸 Anime", "🌃 Cyberpunk"],
            label="Choose Dream Style"
        )

    with gr.Row():
        btn = gr.Button("🎨 Visualize Dream")
        surprise = gr.Button("✨ Surprise Me!")

    output = gr.Image(label="🌟 Your Dream Visualization")
    download = gr.File(label="⬇️ Download Your Dream")

    # Button actions
    btn.click(generate, inputs=[prompt, style], outputs=[output, download])
    surprise.click(surprise_prompt, outputs=[prompt, style])

demo.launch()
# Out:
# It looks like you are running Gradio on a hosted Jupyter notebook, which requires `share=True`. Automatically setting `share=True` (you can turn this off by setting `share=False` in `launch()` explicitly).
#
# Colab notebook detected. To show errors in colab notebook, set debug=True in launch()
# * Running on public URL: https://e1f6f2e5df54df7796.gradio.live
#
# This share link expires in 1 week. For free permanent hosting and GPU upgrades, run `gradio deploy` from the terminal in the working directory to deploy to Hugging Face Spaces (https://huggingface.co/spaces)
# <div><iframe src="https://e1f6f2e5df54df7796.gradio.live" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
